# %%
import yfinance as yf
import pandas as pd
import requests
import google.generativeai as genai
import matplotlib.pyplot as plt
from datetime import datetime

# %%
btc = yf.Ticker("BTC-CAD")
price_data = btc.history(period="1mo")
price_data.reset_index(inplace=True)
price_data['Date'] = price_data['Date'].dt.strftime('%Y-%m-%d')
price_data.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2024-10-05  82315.531250  84811.828125  81909.375000  84296.945312
# 1  2024-10-06  84297.125000  84709.203125  83783.703125  84327.460938
# 2  2024-10-07  84320.726562  85426.687500  83978.695312  85317.937500
# 3  2024-10-08  85318.148438  87697.187500  84676.203125  84771.804688
# 4  2024-10-09  84751.359375  86227.554688  84465.007812  84839.335938
#
#         Volume  Dividends  Stock Splits
# 0  40181509494        0.0           0.0
# 1  18070743608        0.0           0.0
# 2  20068430412        0.0           0.0
# 3  46656366589        0.0           0.0
# 4  38416781793        0.0           0.0

# %%
def fetch_btc_news():
    url = "https://newsapi.org/v2/everything"
    params = {
        'q': 'Bitcoin OR BTC',
        'from': '2024-10-05',
        'to': '2024-11-04',
        'sortBy': 'popularity',
        'apiKey': 'c90c4b9e108540ed850c630041057351'
    }
    
    response = requests.get(url, params=params)
    
    if response.status_code == 200:
        news_data = response.json()
        articles = news_data['articles']
        
        news_list = [{
            'title': article['title'],
            'description': article['description'],
            'date': datetime.fromisoformat(article['publishedAt'].replace('Z', '+00:00')).strftime('%Y-%m-%d')
        } for article in articles]
        return pd.DataFrame(news_list)
    else:
        print(f"Error fetching news: {response.status_code} - {response.text}")
        return pd.DataFrame()

news_data = fetch_btc_news()
news_data.head()
# Out:
#                                                title  \
# 0                                          [Removed]
# 1  Ubisoft stealth released an NFT game absolutel...
# 2  Meet ZachXBT, the Masked Vigilante Tracking Do...
# 3  Peter Todd Was ‘Unmasked’ As Bitcoin Creator S...
# 4           Pig Butchering Scams Are Going High Tech
#
#                                          description        date
# 0                                          [Removed]  2024-10-17
# 1  A new tactical RPG game for PCs from Ubisoft r...  2024-10-30
# 2  He just untangled a $243 million bitcoin theft...  2024-10-24
# 3  Peter Todd has gone underground after an HBO d...  2024-10-22
# 4  Scammers in Southeast Asia are increasingly tu...  2024-10-12

# %%
def prepare_data_for_llm(price_data, news_data):
    price_str = "\n".join(f"{row['Date']}: {row['Close']}" for index, row in price_data.iterrows())
    news_str = "\n".join(f"{row['date']}: {row['title']} - {row['description']}" for index, row in news_data.iterrows())
    return price_str, news_str

price_str, news_str = prepare_data_for_llm(price_data, news_data)

# %%
genai.configure(api_key="AIzaSyB9qzpBBxqIXDr3E_HRtP_BDSGWEWGqhLo")
model = genai.GenerativeModel("gemini-1.5-flash")
prompt = (
    "Analyze the following Bitcoin price data:\n"
    f"{price_data}\n\n"
    "And the following Bitcoin news:\n"
    f"{news_data}\n\n"
    "Provide insights on the correlation between Bitcoin price movements and the news in the following format, without any disclaimers:\n"
    "- [Date]: [Brief description of price movement] following the news about [specific news event], suggesting [analysis of investor sentiment or market implications].\n"
    "\n"
    "For example:\n"
    "- November 2nd: The price surged by 5% following the announcement of major institutional investment in Bitcoin, indicating strong confidence from large players in the market.\n"
    "- November 1st: A decline of 3% occurred after reports emerged about regulatory scrutiny on cryptocurrency exchanges, reflecting investor concerns about potential crackdowns.\n"
    "- October 30th: Following news of a high-profile hack on a crypto exchange, the price dropped by 4%, suggesting heightened fears regarding the security of digital assets.\n"
    "- October 28th: A price increase of 6% aligned with the announcement of a new Bitcoin ETF approval, highlighting positive sentiment around mainstream adoption of Bitcoin.\n"
    "- October 25th: After negative news regarding environmental concerns over Bitcoin mining, the price fell by 2%, indicating growing awareness and concern among environmentally conscious investors."
)
response = model.generate_content(prompt)

# %%
plt.figure(figsize=(12, 6))
plt.plot(price_data['Date'], price_data['Close'], marker='o', linestyle='-', color='blue', label='BTC-CAD Closing Price')
plt.title('Bitcoin Price (BTC-CAD) - Last 30 Days')
plt.xlabel('Date')
plt.ylabel('Price in CAD')
plt.xticks(rotation=45)
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
print(response.text)
# Out:
# - **October 17th:**  A slight upward movement following news of a Peter Todd 'unmasking', suggesting investors are not particularly fazed by the revelation.
# - **October 30th:** A significant surge following the news of Ubisoft's stealth-released NFT game, indicating a potential influx of interest from the gaming industry.
# - **October 24th:** A dip in price after the news of ZachXBT's uncovering of a $243 million Bitcoin theft, reflecting concern over the security of the cryptocurrency.
# - **October 12th:**  A slight price increase following news of "Pig Butchering Scams" going high tech,  possibly indicating investors seeing this as a positive sign of wider adoption, even if through criminal means.
# - **October 07th:** A price rise following the report on private intelligence companies becoming the "new surveillance state," suggesting possible investor interest in Bitcoin's perceived privacy benefits.
# - **October 14th:**  A moderate increase in price followed by the news of 'Scale Ruins Everything,' suggesting a possible influx of investors interested in the implications of scaling for Bitcoin and the wider crypto space.
# - **October 29th:** A significant surge following the news of a recent BGP leak, perhaps indicating investors seeing this as a catalyst for greater security awareness and potential regulatory action.
# - **October 11th:**  A slight drop after the news of the GPU rental bubble bursting, potentially reflecting a loss of confidence in certain aspects of the crypto industry.
